# %% [markdown]
# <a href="https://colab.research.google.com/github/hoGodoy/IA/blob/master/imagensprocess.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pillow

# %%
import PIL

# %%
from PIL import  Image

# %%
 image = Image.open("sample_data/Img/baralho_completo.jpg")

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1022x451 at 0x7F1A923992E8>

# %%
print(image.format)
# Out:
# JPEG

# %%
print(image.mode)
# Out:
# RGB

# %%
print(image.size)
# Out:
# (1022, 451)

# %%
from matplotlib import image
from matplotlib import pyplot

# %%
data = image.imread("sample_data/Img/baralho_completo.jpg")

# %%
print(data)
# Out:
# [[[255 248 255]
#   [255 246 255]
#   [255 248 252]
#   ...
#   [254 252 255]
#   [254 255 255]
#   [251 255 255]]
#
#  [[255 246 255]
#   [255 249 254]
#   [255 250 254]
#   ...
#   [254 254 255]
#   [254 255 255]
#   [251 254 255]]
#
#  [[255 248 252]
#   [255 250 254]
#   [255 254 255]
#   ...
#   [254 254 254]
#   [253 254 255]
#   [250 253 255]]
#
#  ...
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]
